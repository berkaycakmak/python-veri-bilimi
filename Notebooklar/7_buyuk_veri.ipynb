# %% [markdown]
# # **Büyük Veri**

# %% [markdown]
# ## **Büyük Veri Nedir?**

# %% [markdown]
# Geleneksel yöntemlerle işlenemeyen verilere büyük veri denir. Bu açıklamaya göre büyük veri bir problemdir. Eğer büyük veri bir problem ise bu problemin çözümü birden fazla bilgisayarın bir araya gelerek tek bir bilgisayar gibi hareket etmesidir. Yani bir işi yapmak için birden fazla bilgisayarın tek bir bilgisayar gibi davranmasıdır.
#
# Ortaya çıkan veri işleme güçlüğü verinin hacmi (volume), çeşitliliği (variety) ve hızı (velocity) ile alakalıdır. Büyük veriyi ifade eden özellikler hacim, çeşitlilik ve hızdır. **Çok yaygın bir yanılgı bu özelliklerin birlikte olduğunda ancak veriye büyük veri denilebileceğidir.**

# %% [markdown]
# ## **Apache Hadoop**

# %% [markdown]
# Apache Hadoop açık kaynak kodlu, güvenilir, ölçeklenebilir paralel hesaplama yazılımı projesidir. Büyük veri teknolojilerinin temelini oluşturur. Geleneksel yöntemler ile etkin olarak işlenmesi mümkün olmayan verilerin işlenebilmesine olanak sağlamaktadır. Bir bilgisayar kümesinin belirli bir işi yapmak için tek bir bilgisayar gibi birlikte hareket etmesini sağlamaktadır.

# %% [markdown]
# ### Apache Hadoop Bileşenleri

# %% [markdown]
# * Hadoop Common: Tüm diğer Hadoop modellerini destekleyen ortak gereksinimlerdir.
#
# * Hadoop Dağıtık Dosya Sistemi (HDFS): Büyük boyutlardaki veriyi dağıtık bir biçimde kontrol etmeye olanak sağyalan bir dosya sistemidir.
#
# * Hadoop YARN: Kaynak yönetimi ve iş planlaması için kullanılır.
#
# * Hadoop MapReduce: Aynı ağdaki dağıtık bilgisayar kümeleri üzerinde büyük veri analizi yapılabilmesi için geliştirilmiş bir programlama modelidir.

# %% [markdown]
# ### MapReduce Nedir?

# %% [markdown]
# ![Ekran Alıntısı.PNG](attachment:d104c368-067b-4524-a42e-787356da5aab.PNG)

# %% [markdown]
# ## **Apache Spark**

# %% [markdown]
# Apache Spark küme üzerinde hızlı ve genel amaçlı bilgi işleme sistemidir. MapReduce modelinde yer alan disk bazlı çalışma sisteminin yarattığı maliyetlerden dolayı ortaya çıkmıştır. Apache Hadoop'a göre 100 kat hızlı çalışmaktadır. Java, Scala, **Python** ve R ile uygulama geliştirilebilir.

# %% [markdown]
# ### Apache Spark'ın Bileşenleri

# %% [markdown]
# * Spark Core ve RDD's: Apache Spark'ın temel yapısını oluşturan bir kütüphanedir. RDD's sistemi ile işlemlerin hepsi bitirilmeden bir RAM'de saklanır. Tüm işlemlerin bitirildiği, başka bir işlemin olmayacağı bilgisi geldiğinde, veri RAM'den diske aktarılır.
#
# * Spark SQL: SQL veya bir dataframe api kullanarak Spark programındaki yapılandırılmış veriyi sorgulama imkânı sağlar.
#
# * Spark MLlib: Apache Spark'ın ölçeklendirilebilir makine öğrenmesi kütüphanesidir.
#
# * Spark Streaming: Akan verinin ölçeklenebilir, yüksek hacimli ve hata töleranslı olarak işlenmesine imkân sağlayan temel bir Spark api'ıdır.
#
# * GraphX: Grafikler için kullanılan bir kütüphanedir.

# %% [markdown]
# ### Dayanıklı Dağıtık Datasetler (RDD's)

# %% [markdown]
# ![Ekran Alıntısı.PNG](attachment:08172d14-6e0e-4654-aa4a-a9d7fcb39267.PNG)

# %% [markdown]
# Tüm işlemler yapılarak bekletilir ardından işlemlerin bittiğini ifade eden bir komut ile işlemler bitirilir. (Mutfaktan eşya getirme örneği)

# %% [markdown]
# ### MapReduce vs RDD's

# %% [markdown]
# ![Ekran Alıntısı.PNG](attachment:3922ee97-44c3-4ad6-8ae1-b87405e2c850.PNG)

# %% [markdown]
# ## **Ekosistemin Diğer Üyeleri**

# %% [markdown]
# ![Ekran Alıntısı.PNG](attachment:9f30fcdd-ad58-46fc-a8a6-8b64a3644e4c.PNG)

# %% [markdown]
# * Flume: Yapısal olmayan veya yarı yapısal veriler Flume adı verilen bir program ile HDFS'e aktarılır.
#
# * Sqoop (SQL-to-Hadoop): Yapısal verileri HDFS ortamına aktarmak veya HDFS'den almak için kullanılır.
#
# * Apache Ambari ve Zookeeper: Apache Hadoop kümesinin kurulumu, yönetimi ve gözetimi için geliştirilmiş web tabanlı araçlardır. Sistem yönetim işlerinin sağlandığı bileşendir.
#
# * Oozie: İş zamanı programlama (job scheduling) işlemleri için kullanılan bir araçtır.
#
# * Hbase: No-SQL database olarak ifade edilmiş sütun bazlı bir veri tabanıdır.
#
# * Pig: My-SQL tarzı işlemler yapmak için kullanılabilen bir scripting dilidir.
#
# * Hive: Arka planda SQL komutlarını MapReduce'a çevirerek büyük veri üzerinde SQL sorgulamaları yapılabilmesini sağlayan bir programdır.
#
# * Mahout: Hadoop'un makine öğrenmesi aracıdır.
#
# * Kafka & Storm: Akan veride kullanılan bir programdır.

# %% [markdown]
# ### PySpark

# %% [markdown]
# Apache Spark ile Python'un bir araya gelip büyük veri üzerinde makine öğrenmesi, keşifçi veri analizi, veri ön işleme gibi işlemleri Python üzerinde yapılmasını sağlayan bir aracıdır.

# %% [markdown]
# ## **Konfigürasyon ve Spark Bağlantısı**

# %%
# !pip install findspark

# %%
import findspark
findspark.init("C:\spark")

# %%
from pyspark import SparkContext
sc = SparkContext(master = "local")

# %%
sc
# Out:
# <SparkContext master=local appName=pyspark-shell>

# %%
sc.version
# Out:
# '3.1.2'

# %%
sc.sparkUser()
# Out:
# 'brkay'

# %%
sc.appName
# Out:
# 'pyspark-shell'

# %% [markdown]
# İş bittikten sonra kapatmak;

# %%
sc.stop()

# %% [markdown]
# **Uygulama**

# %%
import pyspark
from pyspark.sql import SparkSession
from pyspark.conf import SparkConf
from pyspark import SparkContext

spark = SparkSession.builder \
    .master("local") \
    .appName("pyspark_uygulama") \
    .getOrCreate()


sc = spark.sparkContext
sc
# Out:
# <SparkContext master=local appName=pyspark_uygulama>

# %% [markdown]
# ## **Temel DataFrame İşlemleri**

# %%
spark_df = spark.read.csv("diabetes.csv", header = True, inferSchema = True)

# %%
spark_df.printSchema()
# Out:
# root
#  |-- Pregnancies: integer (nullable = true)
#  |-- Glucose: integer (nullable = true)
#  |-- BloodPressure: integer (nullable = true)
#  |-- SkinThickness: integer (nullable = true)
#  |-- Insulin: integer (nullable = true)
#  |-- BMI: double (nullable = true)
#  |-- DiabetesPedigreeFunction: double (nullable = true)
#  |-- Age: integer (nullable = true)
#  |-- Outcome: integer (nullable = true)

# %%
type(spark_df)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
spark_df.cache()
# Out:
# DataFrame[Pregnancies: int, Glucose: int, BloodPressure: int, SkinThickness: int, Insulin: int, BMI: double, DiabetesPedigreeFunction: double, Age: int, Outcome: int]

# %% [markdown]
# #### Spark vs Pandas DataFrame

# %%
import seaborn as sns
df = sns.load_dataset("diamonds")
df = df.select_dtypes(include = ["float64", "int64"])

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    carat  depth  table  price     x     y     z
# 0   0.23   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31   63.3   58.0    335  4.34  4.35  2.75

# %%
spark_df.head()
# Out:
# Row(Pregnancies=6, Glucose=148, BloodPressure=72, SkinThickness=35, Insulin=0, BMI=33.6, DiabetesPedigreeFunction=0.627, Age=50, Outcome=1)

# %%
df.dtypes
# Out:
# carat    float64
# depth    float64
# table    float64
# price      int64
# x        float64
# y        float64
# z        float64
# dtype: object

# %%
spark_df.dtypes
# Out:
# [('Pregnancies', 'int'),
#  ('Glucose', 'int'),
#  ('BloodPressure', 'int'),
#  ('SkinThickness', 'int'),
#  ('Insulin', 'int'),
#  ('BMI', 'double'),
#  ('DiabetesPedigreeFunction', 'double'),
#  ('Age', 'int'),
#  ('Outcome', 'int')]

# %%
df.ndim
# Out:
# 2

# %%
spark_df.ndim
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-1d8d3a0cd3e5> in <module>
# ----> 1 spark_df.ndim
#
# C:\spark\python\pyspark\sql\dataframe.py in __getattr__(self, name)
#    1641         """
#    1642         if name not in self.columns:
# -> 1643             raise AttributeError(
#    1644                 "'%s' object has no attribute '%s'" % (self.__class__.__name__, name))
#    1645         jc = self._jdf.apply(name)
#
# AttributeError: 'DataFrame' object has no attribute 'ndim'

# %%
df.size
# Out:
# 377580

# %%
spark_df.size
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-ae06dc70f78f> in <module>
# ----> 1 spark_df.size
#
# C:\spark\python\pyspark\sql\dataframe.py in __getattr__(self, name)
#    1641         """
#    1642         if name not in self.columns:
# -> 1643             raise AttributeError(
#    1644                 "'%s' object has no attribute '%s'" % (self.__class__.__name__, name))
#    1645         jc = self._jdf.apply(name)
#
# AttributeError: 'DataFrame' object has no attribute 'size'

# %% [markdown]
# ### Spark DF Değişken Seçme İşlemleri

# %%
spark_df.show(2, truncate = True)
# Out:
# +-----------+-------+-------------+-------------+-------+----+------------------------+---+-------+
# |Pregnancies|Glucose|BloodPressure|SkinThickness|Insulin| BMI|DiabetesPedigreeFunction|Age|Outcome|
# +-----------+-------+-------------+-------------+-------+----+------------------------+---+-------+
# |          6|    148|           72|           35|      0|33.6|                   0.627| 50|      1|
# |          1|     85|           66|           29|      0|26.6|                   0.351| 31|      0|
# +-----------+-------+-------------+-------------+-------+----+------------------------+---+-------+
# only showing top 2 rows

# %%
spark_df.count()
# Out:
# 768

# %%
spark_df.columns
# Out:
# ['Pregnancies',
#  'Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age',
#  'Outcome']

# %%
spark_df.describe().show()
# Out:
# +-------+------------------+-----------------+------------------+------------------+------------------+------------------+------------------------+------------------+------------------+
# |summary|       Pregnancies|          Glucose|     BloodPressure|     SkinThickness|           Insulin|               BMI|DiabetesPedigreeFunction|               Age|           Outcome|
# +-------+------------------+-----------------+------------------+------------------+------------------+------------------+------------------------+------------------+------------------+
# |  count|               768|              768|               768|               768|               768|               768|                     768|               768|               768|
# |   mean|3.8450520833333335|     120.89453125|       69.10546875|20.536458333333332| 79.79947916666667|31.992578124999977|      0.4718763020833327|33.240885416666664|0.3489583333333333|
# ...

# %%
spark_df.describe("Glucose").show()
# Out:
# +-------+-----------------+
# |summary|          Glucose|
# +-------+-----------------+
# |  count|              768|
# |   mean|     120.89453125|
# | stddev|31.97261819513622|
# |    min|                0|
# |    max|              199|
# +-------+-----------------+

# %%
spark_df.select("Glucose", "Pregnancies").show(5)
# Out:
# +-------+-----------+
# |Glucose|Pregnancies|
# +-------+-----------+
# |    148|          6|
# |     85|          1|
# |    183|          8|
# |     89|          1|
# |    137|          0|
# +-------+-----------+
# only showing top 5 rows

# %%
spark_df.select("Glucose").distinct().count()
# Out:
# 136

# %%
spark_df.select("Glucose").dropDuplicates().show()
# Out:
# +-------+
# |Glucose|
# +-------+
# |    148|
# |     85|
# |    137|
# |     65|
# |    133|
# |     78|
# |    155|
# |    108|
# |    193|
# |    115|
# |    126|
# |    101|
# |     81|
# |    183|
# |     76|
# |    159|
# |     44|
# |    103|
# |     91|
# |    128|
# +-------+
# only showing top 20 rows

# %%
spark_df.crosstab("Outcome", "Pregnancies").show()
# Out:
# +-------------------+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+
# |Outcome_Pregnancies|  0|  1| 10| 11| 12| 13| 14| 15| 17|  2|  3|  4|  5|  6|  7|  8|  9|
# +-------------------+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+
# |                  1| 38| 29| 10|  7|  4|  5|  2|  1|  1| 19| 27| 23| 21| 16| 25| 22| 18|
# |                  0| 73|106| 14|  4|  5|  5|  0|  0|  0| 84| 48| 45| 36| 34| 20| 16| 10|
# +-------------------+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+---+

# %%
spark_df.dropna().show(3)
# Out:
# +-----------+-------+-------------+-------------+-------+----+------------------------+---+-------+
# |Pregnancies|Glucose|BloodPressure|SkinThickness|Insulin| BMI|DiabetesPedigreeFunction|Age|Outcome|
# +-----------+-------+-------------+-------------+-------+----+------------------------+---+-------+
# |          6|    148|           72|           35|      0|33.6|                   0.627| 50|      1|
# |          1|     85|           66|           29|      0|26.6|                   0.351| 31|      0|
# |          8|    183|           64|            0|      0|23.3|                   0.672| 32|      1|
# +-----------+-------+-------------+-------------+-------+----+------------------------+---+-------+
# only showing top 3 rows

# %% [markdown]
# ### Spark DF Gözlem Seçme İşlemleri

# %%
spark_df.filter(spark_df.Age > 40).count()
# Out:
# 194

# %%
spark_df.groupby("Outcome").count().show()
# Out:
# +-------+-----+
# |Outcome|count|
# +-------+-----+
# |      1|  268|
# |      0|  500|
# +-------+-----+

# %%
spark_df.groupby("Outcome").agg({"BMI": "mean"}).show()
# Out:
# +-------+-----------------+
# |Outcome|         avg(BMI)|
# +-------+-----------------+
# |      1|35.14253731343278|
# |      0|30.30419999999996|
# +-------+-----------------+

# %% [markdown]
# Yeni değişken ekleme;

# %%
spark_df.withColumn("yeni_degisken", spark_df.BMI/2).select("BMI", "yeni_degisken").show(5)
# Out:
# +----+-------------+
# | BMI|yeni_degisken|
# +----+-------------+
# |33.6|         16.8|
# |26.6|         13.3|
# |23.3|        11.65|
# |28.1|        14.05|
# |43.1|        21.55|
# +----+-------------+
# only showing top 5 rows

# %% [markdown]
# Var olan değişkenin ismini değiştirme;

# %%
spark_df.withColumnRenamed("Outcome", "bagimli_degisken").columns
# Out:
# ['Pregnancies',
#  'Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age',
#  'bagimli_degisken']

# %%
spark_df.head()
# Out:
# Row(Pregnancies=6, Glucose=148, BloodPressure=72, SkinThickness=35, Insulin=0, BMI=33.6, DiabetesPedigreeFunction=0.627, Age=50, Outcome=1)

# %%
spark_df.show(3)
# Out:
# +-----------+-------+-------------+-------------+-------+----+------------------------+---+-------+
# |Pregnancies|Glucose|BloodPressure|SkinThickness|Insulin| BMI|DiabetesPedigreeFunction|Age|Outcome|
# +-----------+-------+-------------+-------------+-------+----+------------------------+---+-------+
# |          6|    148|           72|           35|      0|33.6|                   0.627| 50|      1|
# |          1|     85|           66|           29|      0|26.6|                   0.351| 31|      0|
# |          8|    183|           64|            0|      0|23.3|                   0.672| 32|      1|
# +-----------+-------+-------------+-------------+-------+----+------------------------+---+-------+
# only showing top 3 rows

# %% [markdown]
# Değişken silme;

# %%
spark_df.drop("Insulin").columns
# Out:
# ['Pregnancies',
#  'Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age',
#  'Outcome']

# %% [markdown]
# SparkDF'den PandasDF'e çevirmek;

# %%
a = spark_df.groupby("Outcome").count().toPandas()
a
# Out:
#    Outcome  count
# 0        1    268
# 1        0    500

# %%
a.iloc[0:1, 0:1]
# Out:
#    Outcome
# 0        1

# %% [markdown]
# ## **SQL İşlemleri**

# %%
sc
# Out:
# <SparkContext master=local appName=pyspark_uygulama>

# %%
spark_df.registerTempTable("table_df")

# %%
spark.sql("show databases").show()
# Out:
# +---------+
# |namespace|
# +---------+
# |  default|
# +---------+

# %%
spark.sql("show tables").show()
# Out:
# +--------+---------+-----------+
# |database|tableName|isTemporary|
# +--------+---------+-----------+
# |        | table_df|       true|
# +--------+---------+-----------+

# %%
spark.sql("select Glucose from table_df").show(5)
# Out:
# +-------+
# |Glucose|
# +-------+
# |    148|
# |     85|
# |    183|
# |     89|
# |    137|
# +-------+
# only showing top 5 rows

# %%
spark.sql("select Outcome, mean(Glucose) from table_df group by Outcome").show(5)
# Out:
# +-------+------------------+
# |Outcome|     mean(Glucose)|
# +-------+------------------+
# |      1|141.25746268656715|
# |      0|            109.98|
# +-------+------------------+

# %% [markdown]
# ## **Büyük Veri Görselleştirme**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Büyük veri görselleştirmek için veri ilk olarak Spark ile nihai görselleştirmek istenen şekle dönüştürülür, bu işlemden sonra toPandas ile Pandas serisine dönüştürüp görselleştirilir.
#
# Spark DataFrame üzerinden veri görselleştirme yapılamaz yapılmaya çalışıldığında hata verir;

# %%
sns.barplot(x = "Outcome", y = spark_df.Outcome.index, data = spark_df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-72-e837afc30a4f> in <module>
# ----> 1 sns.barplot(x = "Outcome", y = spark_df.Outcome.index, data = spark_df)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3167 ):
#    3168
# -> 3169     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3170                           estimator, ci, n_boot, units, seed,
# ...

# %% [markdown]
# Buradaki veri küçük olduğu için Spark ile dönüştürülmeden Pandas'a aktarılabilir.

# %%
sdf = spark_df.toPandas()
sdf.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0            6      148             72  ...                     0.627   50        1
# 1            1       85             66  ...                     0.351   31        0
# 2            8      183             64  ...                     0.672   32        1
# 3            1       89             66  ...                     0.167   21        0
# 4            0      137             40  ...                     2.288   33        1
#
# [5 rows x 9 columns]

# %%
sns.barplot(x = "Outcome", y = sdf.Outcome.index, data = sdf);

# %% [markdown]
# ## **Uçtan Uca Büyük Veride Makine Öğrenmesi**

# %% [markdown]
# ### **Spark Session ve Veri Seti**

# %%
sc.stop()

# %%
import pyspark
from pyspark.sql import SparkSession
from pyspark.conf import SparkConf
from pyspark import SparkContext

spark = SparkSession.builder \
    .master("local") \
    .appName("churn_modellemesi") \
    .config("spark.executer.memory", "16gb") \
    .getOrCreate()



sc = spark.sparkContext
sc
# Out:
# <SparkContext master=local appName=pyspark_uygulama>

# %%
spark_df = spark.read.csv("churn.csv", 
                          header = True, 
                          inferSchema = True,
                          sep = ",")
spark_df.cache()
# Out:
# DataFrame[_c0: int, Names: string, Age: double, Total_Purchase: double, Account_Manager: int, Years: double, Num_Sites: double, Churn: int]

# %%
spark_df.printSchema()
# Out:
# root
#  |-- _c0: integer (nullable = true)
#  |-- Names: string (nullable = true)
#  |-- Age: double (nullable = true)
#  |-- Total_Purchase: double (nullable = true)
#  |-- Account_Manager: integer (nullable = true)
#  |-- Years: double (nullable = true)
#  |-- Num_Sites: double (nullable = true)
#  |-- Churn: integer (nullable = true)

# %%
spark_df.show(5)
# Out:
# +---+----------------+----+--------------+---------------+-----+---------+-----+
# |_c0|           Names| Age|Total_Purchase|Account_Manager|Years|Num_Sites|Churn|
# +---+----------------+----+--------------+---------------+-----+---------+-----+
# |  0|Cameron Williams|42.0|       11066.8|              0| 7.22|      8.0|    1|
# |  1|   Kevin Mueller|41.0|      11916.22|              0|  6.5|     11.0|    1|
# |  2|     Eric Lozano|38.0|      12884.75|              0| 6.67|     12.0|    1|
# |  3|   Phillip White|42.0|       8010.76|              0| 6.71|     10.0|    1|
# |  4|  Cynthia Norton|37.0|       9191.58|              0| 5.56|      9.0|    1|
# +---+----------------+----+--------------+---------------+-----+---------+-----+
# only showing top 5 rows

# %% [markdown]
# Önce tüm değişkenleri küçük harfe çevirelim;

# %%
spark_df = spark_df.toDF(*[c.lower() for c in spark_df.columns])

# %%
spark_df.show(5)
# Out:
# +---+----------------+----+--------------+---------------+-----+---------+-----+
# |_c0|           names| age|total_purchase|account_manager|years|num_sites|churn|
# +---+----------------+----+--------------+---------------+-----+---------+-----+
# |  0|Cameron Williams|42.0|       11066.8|              0| 7.22|      8.0|    1|
# |  1|   Kevin Mueller|41.0|      11916.22|              0|  6.5|     11.0|    1|
# |  2|     Eric Lozano|38.0|      12884.75|              0| 6.67|     12.0|    1|
# |  3|   Phillip White|42.0|       8010.76|              0| 6.71|     10.0|    1|
# |  4|  Cynthia Norton|37.0|       9191.58|              0| 5.56|      9.0|    1|
# +---+----------------+----+--------------+---------------+-----+---------+-----+
# only showing top 5 rows

# %% [markdown]
# Pandas DF'de küçük harfe çevirme işlemi;

# %%
#df.columns = map(str.lower, df.columns)

# %% [markdown]
# _c0 değişkenini index olarak adlandıralım;

# %%
spark_df = spark_df.withColumnRenamed("_c0", "index")

# %%
spark_df.show(5)
# Out:
# +-----+----------------+----+--------------+---------------+-----+---------+-----+
# |index|           names| age|total_purchase|account_manager|years|num_sites|churn|
# +-----+----------------+----+--------------+---------------+-----+---------+-----+
# |    0|Cameron Williams|42.0|       11066.8|              0| 7.22|      8.0|    1|
# |    1|   Kevin Mueller|41.0|      11916.22|              0|  6.5|     11.0|    1|
# |    2|     Eric Lozano|38.0|      12884.75|              0| 6.67|     12.0|    1|
# |    3|   Phillip White|42.0|       8010.76|              0| 6.71|     10.0|    1|
# |    4|  Cynthia Norton|37.0|       9191.58|              0| 5.56|      9.0|    1|
# +-----+----------------+----+--------------+---------------+-----+---------+-----+
# only showing top 5 rows

# %%
spark_df.count()
# Out:
# 900

# %%
len(spark_df.columns)
# Out:
# 8

# %% [markdown]
# Bütün gözlem birimleri eşsiz mi?;

# %%
spark_df.distinct().count()
# Out:
# 900

# %% [markdown]
# Bütün kişiler eşsiz mi?;

# %%
spark_df.select("names").distinct().count()
# Out:
# 899

# %% [markdown]
# Burada bütün kişilerin eşsiz olmadığını anladık.
#
# Hangi ismin 2 defa kullanıldığını bulmak için;

# %%
spark_df.groupby("names").count().sort("count", ascending = False).show(3)
# Out:
# +----------------+-----+
# |           names|count|
# +----------------+-----+
# |   Jennifer Wood|    2|
# |     John Barber|    1|
# |Patrick Robinson|    1|
# +----------------+-----+
# only showing top 3 rows

# %% [markdown]
# Jennifer Wood 2 defa kullanılmış fakat bunun bir çoklama mı yoksa aynı ismi taşıyan farklı gözlem birimi mi olduğunu analiz etmemiz gerekiyor. Analiz için bu isimdeki gözlem birimlerinin getirilmesi;

# %%
spark_df.filter(spark_df.names == "Jennifer Wood").show()
# Out:
# +-----+-------------+----+--------------+---------------+-----+---------+-----+
# |index|        names| age|total_purchase|account_manager|years|num_sites|churn|
# +-----+-------------+----+--------------+---------------+-----+---------+-----+
# |   22|Jennifer Wood|35.0|       9381.12|              1| 6.78|     11.0|    1|
# |  439|Jennifer Wood|48.0|      11585.16|              0| 4.61|      9.0|    0|
# +-----+-------------+----+--------------+---------------+-----+---------+-----+

# %% [markdown]
# Görüldüğü üzere bu iki kişi aynı kişi değil. Yani herhangi bir çoklama problemi yok.
#
# Eğer çoklama olsaydı ve biz bu durumdan kurtulmak isteseydik;

# %%
spark_df.select("names").dropDuplicates().groupBy("names").count().sort("count", ascending = False).show(3)
# Out:
# +----------------+-----+
# |           names|count|
# +----------------+-----+
# |    Patrick Bell|    1|
# |Patrick Robinson|    1|
# |   Chelsea Marsh|    1|
# +----------------+-----+
# only showing top 3 rows

# %% [markdown]
# Spark DF'de indexe erişmek;

# %%
spark_df.where(spark_df.index == 439).select("names").show()
# Out:
# +-------------+
# |        names|
# +-------------+
# |Jennifer Wood|
# +-------------+

# %% [markdown]
# Bir indexin değerini başka bir değişkene girdi olarak kullanmak için;

# %%
jen = spark_df.where(spark_df.index == 439).collect()[0]["names"]

# %%
jen
# Out:
# 'Jennifer Wood'

# %%
type(jen)
# Out:
# str

# %%
jen.upper()
# Out:
# 'JENNIFER WOOD'

# %% [markdown]
# ### **Keşifçi Veri Analizi**

# %%
spark_df.describe().show()
# Out:
# +-------+------------------+-------------+-----------------+-----------------+------------------+-----------------+------------------+-------------------+
# |summary|             index|        names|              age|   total_purchase|   account_manager|            years|         num_sites|              churn|
# +-------+------------------+-------------+-----------------+-----------------+------------------+-----------------+------------------+-------------------+
# |  count|               900|          900|              900|              900|               900|              900|               900|                900|
# |   mean|             449.5|         null|41.81666666666667|10062.82403333334|0.4811111111111111| 5.27315555555555| 8.587777777777777|0.16666666666666666|
# | stddev|259.95191863111916|         null|6.127560416916251|2408.644531858096|0.4999208935073339|1.274449013194616|1.7648355920350969| 0.3728852122772358|
# ...

# %%
spark_df.select("age","total_purchase", "account_manager", "years","num_sites","churn").describe().toPandas().transpose()
# Out:
#                      0                    1                   2      3  \
# summary          count                 mean              stddev    min
# age                900    41.81666666666667   6.127560416916251   22.0
# total_purchase     900    10062.82403333334   2408.644531858096  100.0
# account_manager    900   0.4811111111111111  0.4999208935073339      0
# years              900     5.27315555555555   1.274449013194616    1.0
# num_sites          900    8.587777777777777  1.7648355920350969    3.0
# churn              900  0.16666666666666666  0.3728852122772358      0
#
#                         4
# summary               max
# age                  65.0
# total_purchase   18026.01
# account_manager         1
# years                9.15
# num_sites            14.0
# churn                   1

# %%
spark_df.filter(spark_df.age > 47).count()
# Out:
# 161

# %%
spark_df.groupby("churn").count().show()
# Out:
# +-----+-----+
# |churn|count|
# +-----+-----+
# |    1|  150|
# |    0|  750|
# +-----+-----+

# %%
spark_df.groupby("churn").agg({"total_purchase": "mean"}).show()
# Out:
# +-----+-------------------+
# |churn|avg(total_purchase)|
# +-----+-------------------+
# |    1| 10192.179933333337|
# |    0| 10036.952853333332|
# +-----+-------------------+

# %%
spark_df.groupby("churn").agg({"years": "mean"}).show()
# Out:
# +-----+------------------+
# |churn|        avg(years)|
# +-----+------------------+
# |    1|5.8835999999999995|
# |    0|5.1510666666666625|
# +-----+------------------+

# %%
kor_data = spark_df.drop("index","names").toPandas()

# %%
import seaborn as sns
sns.pairplot(kor_data, hue = "churn");

# %%
sns.pairplot(kor_data, vars = ["age", "total_purchase","years","num_sites"], 
             hue = "churn",
            kind = "reg");

# %% [markdown]
# ### **Veri Ön İşleme**

# %%
spark_df = spark_df.dropna()

# %%
spark_df = spark_df.withColumn("age_kare", spark_df.age**2)

# %%
spark_df.show(3)
# Out:
# +-----+----------------+----+--------------+---------------+-----+---------+-----+--------+
# |index|           names| age|total_purchase|account_manager|years|num_sites|churn|age_kare|
# +-----+----------------+----+--------------+---------------+-----+---------+-----+--------+
# |    0|Cameron Williams|42.0|       11066.8|              0| 7.22|      8.0|    1|  1764.0|
# |    1|   Kevin Mueller|41.0|      11916.22|              0|  6.5|     11.0|    1|  1681.0|
# |    2|     Eric Lozano|38.0|      12884.75|              0| 6.67|     12.0|    1|  1444.0|
# +-----+----------------+----+--------------+---------------+-----+---------+-----+--------+
# only showing top 3 rows

# %% [markdown]
# Bağımlı değişkeni (churn) string'e dönüştürmek;
#
# Ayrıca bağımlı değişkenler label, bağımsız değişkenler features olarak adlandırılarak final dataframe oluşturulur.

# %%
from pyspark.ml.feature import StringIndexer

stringIndexer = StringIndexer(inputCol = "churn", outputCol = "label")

# %% [markdown]
# StringIndexer sınıf etiketlerinin en çok gözlenen değerini 0 olarak etiketler.

# %%
indexed = stringIndexer.fit(spark_df).transform(spark_df)

# %%
indexed.dtypes
# Out:
# [('index', 'int'),
#  ('names', 'string'),
#  ('age', 'double'),
#  ('total_purchase', 'double'),
#  ('account_manager', 'int'),
#  ('years', 'double'),
#  ('num_sites', 'double'),
#  ('churn', 'int'),
#  ('age_kare', 'double'),
#  ('label', 'double')]

# %% [markdown]
# Bağımlı değişkeni integer yapmak;

# %%
spark_df = indexed.withColumn("label", indexed["label"].cast("integer"))

# %%
spark_df.dtypes
# Out:
# [('index', 'int'),
#  ('names', 'string'),
#  ('age', 'double'),
#  ('total_purchase', 'double'),
#  ('account_manager', 'int'),
#  ('years', 'double'),
#  ('num_sites', 'double'),
#  ('churn', 'int'),
#  ('age_kare', 'double'),
#  ('label', 'int')]

# %% [markdown]
# Bağımsız değişken ayarlamaları;

# %%
from pyspark.ml.feature import VectorAssembler

# %%
spark_df.columns
# Out:
# ['index',
#  'names',
#  'age',
#  'total_purchase',
#  'account_manager',
#  'years',
#  'num_sites',
#  'churn',
#  'age_kare',
#  'label']

# %%
bag = ["age","total_purchase", "account_manager","years","num_sites"]

# %%
vectorAssembler = VectorAssembler(inputCols = bag, outputCol = "features")

# %%
va_df = vectorAssembler.transform(spark_df)

# %%
final_df = va_df.select(["features", "label"])

# %%
final_df.show()
# Out:
# +--------------------+-----+
# |            features|label|
# +--------------------+-----+
# |[42.0,11066.8,0.0...|    1|
# |[41.0,11916.22,0....|    1|
# |[38.0,12884.75,0....|    1|
# |[42.0,8010.76,0.0...|    1|
# |[37.0,9191.58,0.0...|    1|
# |[48.0,10356.02,0....|    1|
# |[44.0,11331.58,1....|    1|
# |[32.0,9885.12,1.0...|    1|
# |[43.0,14062.6,1.0...|    1|
# |[40.0,8066.94,1.0...|    1|
# |[30.0,11575.37,1....|    1|
# |[45.0,8771.02,1.0...|    1|
# |[45.0,8988.67,1.0...|    1|
# |[40.0,8283.32,1.0...|    1|
# |[41.0,6569.87,1.0...|    1|
# |[38.0,10494.82,1....|    1|
# |[45.0,8213.41,1.0...|    1|
# |[43.0,11226.88,0....|    1|
# |[53.0,5515.09,0.0...|    1|
# |[46.0,8046.4,1.0,...|    1|
# +--------------------+-----+
# only showing top 20 rows

# %% [markdown]
# Spark'ın bizden beklediği bazı makine öğrenmesi fonksiyonlarının sabit bir yapısı var. Bu yapı features ve label yapısıdır.

# %% [markdown]
# ### Test-Train

# %%
splits = final_df.randomSplit([0.7, 0.3])

# %%
train_df = splits[0]
test_df = splits[1]

# %%
train_df
# Out:
# DataFrame[features: vector, label: int]

# %%
test_df
# Out:
# DataFrame[features: vector, label: int]

# %% [markdown]
# ## **GBM ile Müşteri Terk Modellemesi**

# %%
from pyspark.ml.classification import GBTClassifier

# %%
gbm = GBTClassifier(maxIter = 10, featuresCol = "features", labelCol = "label")

# %%
gbm_model = gbm.fit(train_df)

# %%
y_pred = gbm_model.transform(test_df)

# %%
y_pred
# Out:
# DataFrame[features: vector, label: int, rawPrediction: vector, probability: vector, prediction: double]

# %%
ac = y_pred.select("label", "prediction")

# %% [markdown]
# Modelin ilkel test hatası;

# %%
ac.filter(ac.label == ac.prediction).count() / ac.count()
# Out:
# 0.8443579766536965

# %% [markdown]
# Model tuning;

# %%
from pyspark.ml.evaluation import BinaryClassificationEvaluator
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator

evaluator = BinaryClassificationEvaluator()

paramGrid = (ParamGridBuilder()
             .addGrid(gbm.maxDepth, [2, 4, 6])
             .addGrid(gbm.maxBins, [20, 30])
             .addGrid(gbm.maxIter, [10, 20])
             .build())

cv = CrossValidator(estimator= gbm, estimatorParamMaps = paramGrid, evaluator=evaluator, numFolds= 10)

# %%
cv_model = cv.fit(train_df)

# %% [markdown]
# .transform ile tahmin yapıyoruz;

# %%
y_pred = cv_model.transform(test_df)
ac = y_pred.select("label", "prediction")

# %%
ac.filter(ac.label == ac.prediction).count() / ac.count()
# Out:
# 0.8832684824902723

# %%
evaluator.evaluate(y_pred)
# Out:
# 0.8509563138448164

# %% [markdown]
# ### Bu müşteriler bizi terk eder mi?

# %%
import pandas as pd
names = pd.Series(["Ali Ahmetoğlu", "Berkcan Tanerbey", "Harika Gündüz","Polat Alemdar", "Ata Bakmayan Ali"])
age = pd.Series([38, 43, 34, 50, 40])
total_purchase = pd.Series([30000, 10000, 6000, 30000, 100000])
account_manager = pd.Series([1,0,0,1,1])
years = pd.Series([20, 10, 3, 8, 30])
num_sites = pd.Series([30,8,8,6,50])


yeni_musteriler = pd.DataFrame({
    'names':names,
    'age': age,
    'total_purchase': total_purchase,
    'account_manager': account_manager ,
    'years': years,
    'num_sites': num_sites})

yeni_musteriler.columns
# Out:
# Index(['names', 'age', 'total_purchase', 'account_manager', 'years',
#        'num_sites'],
#       dtype='object')

# %%
yeni_musteriler
# Out:
#               names  age  total_purchase  account_manager  years  num_sites
# 0     Ali Ahmetoğlu   38           30000                1     20         30
# 1  Berkcan Tanerbey   43           10000                0     10          8
# 2     Harika Gündüz   34            6000                0      3          8
# 3     Polat Alemdar   50           30000                1      8          6
# 4  Ata Bakmayan Ali   40          100000                1     30         50

# %%
yeni_sdf = spark.createDataFrame(yeni_musteriler)

# %%
type(yeni_sdf)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
yeni_sdf.show()
# Out:
# +----------------+---+--------------+---------------+-----+---------+
# |           names|age|total_purchase|account_manager|years|num_sites|
# +----------------+---+--------------+---------------+-----+---------+
# |   Ali Ahmetoğlu| 38|         30000|              1|   20|       30|
# |Berkcan Tanerbey| 43|         10000|              0|   10|        8|
# |   Harika Gündüz| 34|          6000|              0|    3|        8|
# |   Polat Alemdar| 50|         30000|              1|    8|        6|
# |Ata Bakmayan Ali| 40|        100000|              1|   30|       50|
# +----------------+---+--------------+---------------+-----+---------+

# %%
yeni_musteriler = vectorAssembler.transform(yeni_sdf)

# %%
sonuclar = cv_model.transform(yeni_musteriler)

# %%
sonuclar.select("names", "prediction").show()
# Out:
# +----------------+----------+
# |           names|prediction|
# +----------------+----------+
# |   Ali Ahmetoğlu|       1.0|
# |Berkcan Tanerbey|       0.0|
# |   Harika Gündüz|       0.0|
# |   Polat Alemdar|       0.0|
# |Ata Bakmayan Ali|       1.0|
# +----------------+----------+

# %% [markdown]
# ## **Bazı Diğer Modeller**

# %%
from pyspark.ml.classification import LogisticRegression
loj = LogisticRegression(featuresCol = "features", labelCol = 'label', maxIter=10)
loj_model = loj.fit(train_df)
y_pred = loj_model.transform(test_df)
ac = y_pred.select("label", "prediction")
ac.filter(ac.label == ac.prediction).count() / ac.count()
# Out:
# 0.8129496402877698

# %%
from pyspark.ml.classification import DecisionTreeClassifier
dt = DecisionTreeClassifier(featuresCol = 'features', labelCol = 'label', maxDepth = 3)
dt_model = dt.fit(train_df)
y_pred = dt_model.transform(test_df)
ac = y_pred.select("label", "prediction")
ac.filter(ac.label == ac.prediction).count() / ac.count()
# Out:
# 0.8669064748201439

# %%
from pyspark.ml.classification import RandomForestClassifier
rf = RandomForestClassifier(featuresCol = 'features', labelCol = 'label')
rf_model = rf.fit(train_df)
y_pred = rf_model.transform(test_df)
ac = y_pred.select("label", "prediction")
ac.filter(ac.label == ac.prediction).count() / ac.count()
# Out:
# 0.8489208633093526

# %%
sc.stop()
